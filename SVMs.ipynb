# %%
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.svm import SVC
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, plot_confusion_matrix, confusion_matrix,accuracy_score
import seaborn as sns
from matplotlib import pyplot as plt
from pandas.plotting import radviz

# %%
df = pd.read_csv('combined-dataset.csv')
X = df.drop('y',axis=1)
y = df['y']

#Standartization for our dataset
scaler = StandardScaler()
X = scaler.fit_transform(X)

#splitting dataset into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

#Implementing to dataset
clf = SVC(gamma=2)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6916702324917986

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[7934  336 1105   69  202   64   12  242  780  173    3  298  320]
#  [ 592 2311    0   32  778   28    0  405  724   13    0   25  530]
#  [ 457    0 5150    7    4    0    8    2    0    4    1   16    0]
#  [ 401  115   15 1291  327  634    5  154  106  211    2  238   80]
#  [ 411  755    3  142 3265   73    1  417  293   15    3   12  250]
#  [ 218   32    9  291   74 2395    0   25   28  379    0  264   18]
#  [  18    0    7    0    1    0 5473    0    1    3   38    2    0]
#  [ 579  690    4   95  725   49    0 2036  898    9    0   21  482]
#  [ 432  675    4   23  191    6    5  267 3333    7    3  107  383]
#  [ 114    3    2   26    3   85    3    9    5 4524    1  116    0]
#  [  48    1    5    1    0    1   31    0    1    0 3689    1    0]
#  [ 329   30   15  139   14  351    5   17   94  401    2 4091   53]
#  [ 158  142    0   13  104    3    0   96  210    1    4   24 3001]]
#               precision    recall  f1-score   support
#
#            1       0.68      0.69      0.68     11538
#            2       0.45      0.42      0.44      5438
#            3       0.82      0.91      0.86      5649
#            4       0.61      0.36      0.45      3579
#            5       0.57      0.58      0.58      5640
#            6       0.65      0.64      0.65      3733
#            7       0.99      0.99      0.99      5543
#            8       0.55      0.36      0.44      5588
#            9       0.51      0.61      0.56      5436
#           10       0.79      0.92      0.85      4891
#           11       0.98      0.98      0.98      3778
#           12       0.78      0.74      0.76      5541
#           13       0.59      0.80      0.68      3756
#
#     accuracy                           0.69     70110
#    macro avg       0.69      0.69      0.69     70110
# weighted avg       0.69      0.69      0.68     70110

# %%
from pandas.plotting import radviz
data = pd.read_csv("combined-dataset.csv")
plt.figure();
radviz(data, "y");
